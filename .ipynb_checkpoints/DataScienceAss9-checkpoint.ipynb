# %%
import pandas as pd
import seaborn as sns

# %%
penguins = sns.load_dataset("penguins")

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
Correlation = penguins.corr()
Correlation.style.background_gradient(cmap='coolwarm', axis=None).format(precision=2)
# Out:
# <style type="text/css">
# #T_f27fd_row0_col0, #T_f27fd_row1_col1, #T_f27fd_row2_col2, #T_f27fd_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f27fd_row0_col1, #T_f27fd_row1_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_f27fd_row0_col2, #T_f27fd_row2_col0 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_f27fd_row0_col3, #T_f27fd_row3_col0 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_f27fd_row1_col2, #T_f27fd_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f27fd_row1_col3, #T_f27fd_row3_col1 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_f27fd_row2_col3, #T_f27fd_row3_col2 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f27fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f27fd_level0_col0" class="col_heading level0 col0" >bill_length_mm</th>
# ...

# %%
penguins.plot(kind='scatter', x='bill_length_mm',y='flipper_length_mm')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
penguins.plot(kind='scatter', x='bill_depth_mm',y='flipper_length_mm')
# Out:
# <AxesSubplot:xlabel='bill_depth_mm', ylabel='flipper_length_mm'>

# %%
penguins.plot(kind='scatter', x='bill_length_mm',y='bill_depth_mm')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='bill_depth_mm'>
